# %%
import requests
from bs4 import BeautifulSoup 
import pandas as pd

# %%
url = 'https://www.flipkart.com/search?q=mobile+phone+50000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&as-pos=1&as-type=HISTORY&page='+str(1)
r = requests.get(url)
print(r)
soup = BeautifulSoup(r.text, "lxml")
box = soup.find("div",class_ = "_1YokD2 _3Mn1Gg")
print(box)
# Out:
# <Response [200]>
# ...

# %%
product_name =[]
product_price =[]
product_review = []
product_discounts = []
names = box.find_all("div",class_ = "_4rR01T")
    #for i in names:
     #   name = i.text
     #   product_title.append(name)

# %%
for i in range(2,12):
    url = 'https://www.flipkart.com/search?q=mobile+phone+50000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&as-pos=1&as-type=HISTORY&page='+str(i)
    r = requests.get(url)
    #print(r)
    soup = BeautifulSoup(r.text, "lxml")
    box = soup.find("div",class_ = "_1YokD2 _3Mn1Gg")
    print(soup)
# Out:
# <Response [429]>
# <!DOCTYPE html>
# <html><head><title>Online Shopping India Mobile, Cameras, Lifestyle &amp; more Online @ Flipkart.com</title><meta content="IE=edge" http-equiv="X-UA-Compatible"/><style>html,
#         body {
#             font-family: Roboto, arial, tahoma, verdana, sans-serif;
#             height: 100%;
#             margin: 0;
#         }
#
#         .btn {
#             border-radius: 4px;
#             margin-top: 16px;
#             display: inline-block;
#             color: #fff;
#             font-family: inter_semi_bold, Arial, sans-serif;
#             border: none;
#             font-size: inherit;
#             cursor: pointer;
#             width: 328px;
#             height: 40px;
#         }
#
#         .disable_btn {
#             background-color: #808080;
#             cursor: not-allowed;
#         }
#
#         #retry_btn {
#             background-color: #2A55E5;
#             display: none;
# ...

# %%
 # product_title
    product_title =[]
    names = box.find_all("div",class_ = "_4rR01T")
    for i in names:
        name = i.text
        product_title.append(name)
    #print(product_title)
    print(len(product_title))
    
    #product_price
    product_price =[]
    prices = box.find_all("div",class_ = "_30jeq3 _1_WHN1")
    for i in prices:
        price = i.text
        product_price.append(price)
   # print(product_price)
    #print(len(product_price))
    
    #product_review =[]
    product_review =[]
    review = box.find_all("div",class_ = "_3LWZlK")
    for i in review:
        reviews = i.text
        product_review.append(reviews)    
    #print(product_review)
    #print(len(product_review))
    
    #product_discounts
    product_discounts = []

    discount = box.find_all("div",class_ = "_3Ay6Sb")
    for i in discount:
        dis = i.text
        product_discounts.append(dis)

    #print(product_discounts)

    #product_discription
    product_discription =[]
    discription = box.find_all("ul",class_ = "_1xgFaf")
    for i in discription:
        dis = i.text
        product_discription.append(dis)

    #print(product_discription)
    #print(len(product_discription))

# %%
#next_page :
#next_page = soup.find("a",class_ = "_1LKTO3").get("href")
#print(next_page)
#complate_next_page as cnp
#amta net page teke ja out put paici sei output ar link diye google a search diye amra (https://www.flipkart.com) -> ai host ta asce nai tai amra complate nest page hisabe use korbo
#cnp = "https://www.flipkart.com"+next_page
#print(cnp)

# %%
#using_loop:
for i in range(1,8):
    url = "https://www.flipkart.com/search?q=mobile+under+50000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&as-pos=1&as-type=HISTORY&page="+str(i)
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "lxml")
    next_page = soup.find("a",class_ = "_1LKTO3").get("href")
    cnp = "https://www.flipkart.com"+next_page
    print(cnp)

    #url = cnp
    #r = requests.get(url)
    #soup = BeautifulSoup(r.text, "lxml")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[99], line 6
#       4 r = requests.get(url)
#       5 soup = BeautifulSoup(r.text, "lxml")
# ----> 6 next_page = soup.find("a",class_ = "_1LKTO3").get("href")
#       7 cnp = "https://www.flipkart.com"+next_page
#       8 print(cnp)
#
# AttributeError: 'NoneType' object has no attribute 'get'

# %%
# product_title
product_title =[]
title = box.find_all("div",class_ = "_4rR01T")
for i in title:
    name = i.text
    product_title.append(name)
print(product_title)
print(len(product_title))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[105], line 3
#       1 # product_title
#       2 product_title =[]
# ----> 3 title = box.find_all("div",class_ = "_4rR01T")
#       4 for i in title:
#       5     name = i.text
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
df = pd.DataFrame({"Product Name":product_title,"Price":product_price,"Ratting":product_review,"Discount":product_discounts, "Specification":product_discription})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 df = pd.DataFrame({"Product Name":product_title,"Price":product_price,"Ratting":product_review,"Discount":product_discounts, "Specification":product_discription})
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:709, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     703     mgr = self._init_mgr(
#     704         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     705     )
#     707 elif isinstance(data, dict):
#     708     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710 elif isinstance(data, ma.MaskedArray):
#     711     from numpy.ma import mrecords
#
# ...
